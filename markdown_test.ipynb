# %% [markdown]
# <!-- 這裡的東西看不到 -->
# # 標題一
# ## 標題二
# ![圖: xxx](data:image/jpeg;base64,...)
#
# .[markdown 用法](https://en.wikibooks.org/wiki/LaTeX/Mathematics)
#
# 姓名  | 身高 | 體重
# ---- | ---- | ----
# Alen | 178 | 75
# Jack | 192 | 88
#
# .[Latex Math](https://en.wikibooks.org/wiki/LaTeX/Mathematics)
#
# $ \frac{1}{2} \times \pi R_1^2 $
#
#
# $
# M = \begin{bmatrix}
#        \frac{5}{6} & \frac{1}{6} & 0           \\[0.3em]
#        \frac{5}{6} & 0           & \frac{1}{6} \\[0.3em]
#        0           & \frac{5}{6} & \frac{1}{6}
#      \end{bmatrix}
# $
