# %%
# seaborn.displot (kde=True => 長條突變曲線圖)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
dist = np.random.normal(loc=10, size=100000)
dist = dist[dist>=0]
sns.distplot(dist)

# %%
# numpy.power 右偏左偏 => 可能是次方的影響
from scipy.stats import boxcox_normmax
dist1 = np.power(dist,6)
print(boxcox_normmax(dist1))
sns.distplot(dist1)
# Out:
# 0.16636956747699733

# %%
dist1 = np.power(dist,1/6)
print(boxcox_normmax(dist1))
sns.distplot(dist1)
# Out:
# 5.9893038296447765

# %%
dist2 = np.power(2, dist)
print(boxcox_normmax(dist2))
sns.distplot(dist2)
# Out:
# C:\Users\sore\AppData\Local\Programs\Python\Python37\lib\site-packages\scipy\stats\stats.py:3538: PearsonRNearConstantInputWarning: An input array is nearly constant; the computed correlation coefficent may be inaccurate.
#   warnings.warn(PearsonRNearConstantInputWarning())
# -0.0005039131681540288

# %%
# scipy.special.boxcox1p 搭配 scipy.stats.boxcox_normmax 找到 lamda

# %%
sua = scipy.special.boxcox1p(dist2, lmbda=2) 
sns.distplot(sua)
